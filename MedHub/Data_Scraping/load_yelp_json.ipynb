# %%
import json
import ast
import pandas as pd
from IPython.display import display, HTML

# %%
with open('yelp_1000_doc_sf.json', 'r') as f:
    yelp = pd.DataFrame(json.loads(line) for line in f)

# %%
yelp['phone']
# Out:
# 0      4154521200
# 3
# 4      4153970700
# 5      4159287550
# 6      4156420333
# 7      4152213200
# 9      4159890088
# 10     4157505730
# 11     4158262438
# 12     4155668799
# 13
# 14     4153625443
# 16     4154337000
# 20     4156742600
# 21     4159811102
# 22     4159233673
# 23     4156416566
# 24     4155294050
# 25     4157520100
# 26     4156004900
# 27     4158854971
# 28     4156004760
# 29     4153928200
# 30     4156000140
# 32     4153295100
# 33     4156000140
# 34     4158370888
# 35     4158765762
# 36     4157511446
# 37     4156817707
#           ...
# 939    4156445265
# 942
# 943    4153981115
# 944    4159222391
# 945    4157505570
# 946    4153532318
# 948    4158762748
# 949    4155146200
# 950    4155633800
# 951    4156939485
# 952    4157817850
# 953    4158857788
# 954    4153459400
# 955    4156688010
# 956    4154267859
# 958    4152210665
# 959    4158573228
# 960    4156682118
# 963    4156680160
# 964    4155641261
# 965    4154050200
# ...

# %%
yelp.shape
# Out:
# (640, 19)

# %%
yelp.dtypes
# Out:
# categories        object
# coordinates       object
# display_phone     object
# hours             object
# id                object
# image_url         object
# is_claimed          bool
# is_closed           bool
# location          object
# name              object
# phone             object
# photos            object
# price             object
# rating           float64
# review_count       int64
# transactions      object
# url               object
# First Name        object
# Last Name         object
# dtype: object

# %%
display(yelp.head())
# Out:
#                                           categories  \
# 0  [{u'alias': u'internalmed', u'title': u'Intern...
# 3  [{u'alias': u'internalmed', u'title': u'Intern...
# 4  [{u'alias': u'internalmed', u'title': u'Intern...
# 5  [{u'alias': u'internalmed', u'title': u'Intern...
# 6  [{u'alias': u'familydr', u'title': u'Family Pr...
#
#                                          coordinates   display_phone  \
# 0  {u'latitude': 37.73165, u'longitude': -122.47418}  (415) 452-1200
# 3  {u'latitude': 37.7948471658, u'longitude': -12...
# 4  {u'latitude': 37.784961, u'longitude': -122.40...  (415) 397-0700
# 5  {u'latitude': 37.7858734131, u'longitude': -12...  (415) 928-7550
# 6  {u'latitude': 37.7485771179, u'longitude': -12...  (415) 642-0333
#
#                                                hours  \
# 0                                                NaN
# 3  [{u'hours_type': u'REGULAR', u'open': [{u'is_o...
# 4  [{u'hours_type': u'REGULAR', u'open': [{u'is_o...
# ...

# %% [markdown]
# # Load Vyakha's data

# %%
doctors = pd.read_csv('SanFrancisco.csv')
doctors['Phone Number'] = doctors['Phone Number'].fillna(0).astype('int').astype('str')

# %%
doctors.dtypes
# Out:
# Unnamed: 0                                                              int64
# NPI                                                                     int64
# PAC ID                                                                  int64
# Professional Enrollment ID                                             object
# Last Name                                                              object
# First Name                                                             object
# Middle Name                                                            object
# Suffix                                                                 object
# Gender                                                                 object
# Credential                                                             object
# Medical school name                                                    object
# Graduation year                                                       float64
# ...

# %%
display(doctors.head())
# Out:
#    Unnamed: 0         NPI      PAC ID Professional Enrollment ID   Last Name  \
# 0         246  1285777961  1951564400            I20120518000556   CIANCIOLO
# 1         506  1619034766  3375688245            I20100303000302       HOBBS
# 2         663  1811088214  4385644111            I20061229000452    MENDIVIL
# 3         809  1033240254  8527238500            I20120330000599  NEHREBECKI
# 4         949  1629367701  3173786639            I20120519000007    BRANTNER
#
#   First Name Middle Name Suffix Gender Credential  \
# 0    LEONARD           J    NaN      M        NaN
# 1      DARYL         NaN    NaN      M        NaN
# 2       JUAN           A    NaN      M         MD
# 3      PETER         NaN    NaN      M        NaN
# 4    ZACHARY           J    NaN      M        NaN
#
#                                  ...                                  \
# 0                                ...
# 1                                ...
# 2                                ...
# ...

# %%
display(doctors.head()['Phone Number'])
# Out:
# 0    4153462445
# 1    4154401440
# 2    4156411111
# 3    4156215335
# 4    4155631655
# Name: Phone Number, dtype: object
